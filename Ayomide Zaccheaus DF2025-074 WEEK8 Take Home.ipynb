# %% [markdown]
# ## Provide Notebook-1 Tasks Solutions below (Execute them)

# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

import pandas as pd

table = [
  ['UK', 2678454886796.7],    # 1st row
  ['USA', 16768100000000.0],  # 2nd row
  ['China', 9240270452047.0], # and so on...
  ['Brazil', 2245673032353.8],
  ['South Africa', 366057913367.1]
]

headings = ['Country', 'GDP (US$)']
gdp = pd.DataFrame(columns=headings, data=table)

# %%
headings = ['Country name', 'Life expectancy (years)']
table = [
  ['China', 75],
  ['Russia', 71],
  ['United States', 79],
  ['India', 66],
  ['United Kingdom', 81]
]
life = pd.DataFrame(columns=headings, data=table)

def roundToMillions (value):
    return round(value / 1000000)
def usdToGBP (usd):
    return usd / 1.564768 # average rate during 2013
def expandCountry (name):
    if name == 'UK':
        return 'United Kingdom'
    elif name == 'USA':
        return 'United States'
    else:
        return name

# %%
gdp['Country name'] = gdp['Country'].apply(expandCountry)
gdp['GDP (£m)'] = gdp['GDP (US$)'].apply(usdToGBP).apply(roundToMillions)
gdp['GDP (US$)'].apply(roundToMillions).apply(usdToGBP).apply(round)
headings = ['Country name', 'GDP (£m)']
gdp = gdp[headings]

# %%
gdpVsLife = pd.merge(gdp, life, on='Country name', how='inner')
gdpVsLife
# Out:
#      Country name  GDP (£m)  Life expectancy (years)
# 0  United Kingdom   1711727                       81
# 1   United States  10716029                       79
# 2           China   5905202                       75

# %% [markdown]
# ### Task
#
# Create your population dataframe  `'Country name', 'Life expectancy (years)'`.

# %%
#Creating population dataframe
import pandas as pd
#New population Data
table = [
    ['United Kingdom', 66000000],
    ['United States', 331000000],
    ['China', 1400000000],
    ['India', 1380000000],
    ['Brazil', 213000000],
    ['South Africa', 60000000],
    ['Russia', 146000000]
]

headings = ['Country name', 'Population']
population = pd.DataFrame(columns=headings, data=table)

# %% [markdown]
# ### Task
#
# Join your population dataframe previous task with `gdpVsLife`, in four different ways, and note the differences.

# %%
pd.merge(gdpVsLife, population, on='Country name', how='left')
# Out:
#      Country name  GDP (£m)  Life expectancy (years)  Population
# 0  United Kingdom   1711727                       81    66000000
# 1   United States  10716029                       79   331000000
# 2           China   5905202                       75  1400000000

# %%
pd.merge(gdpVsLife, population, on='Country name', how='right')
# Out:
#      Country name    GDP (£m)  Life expectancy (years)  Population
# 0  United Kingdom   1711727.0                     81.0    66000000
# 1   United States  10716029.0                     79.0   331000000
# 2           China   5905202.0                     75.0  1400000000
# 3           India         NaN                      NaN  1380000000
# 4          Brazil         NaN                      NaN   213000000
# 5    South Africa         NaN                      NaN    60000000
# 6          Russia         NaN                      NaN   146000000

# %%
pd.merge(gdpVsLife, population, on='Country name', how='outer')
# Out:
#      Country name    GDP (£m)  Life expectancy (years)  Population
# 0          Brazil         NaN                      NaN   213000000
# 1           China   5905202.0                     75.0  1400000000
# 2           India         NaN                      NaN  1380000000
# 3          Russia         NaN                      NaN   146000000
# 4    South Africa         NaN                      NaN    60000000
# 5  United Kingdom   1711727.0                     81.0    66000000
# 6   United States  10716029.0                     79.0   331000000

# %%
pd.merge(gdpVsLife, population, on='Country name', how='inner')
# Out:
#      Country name  GDP (£m)  Life expectancy (years)  Population
# 0  United Kingdom   1711727                       81    66000000
# 1   United States  10716029                       79   331000000
# 2           China   5905202                       75  1400000000

# %% [markdown]
# ### Task
#
# Look through the code you wrote so far, and rewrite it using constants, when appropriate.

# %%
#CONSTANTS
COUNTRY = 'Country name'
GDP_USD = 'GDP (US$)'
GDP_GBP = 'GDP (£m)'
LIFE_EXP = 'Life expectancy (years)'
POPULATION = 'Population'

# Create GDP DataFrame
table = [
    ['UK', 2678454886796.7],
    ['USA', 16768100000000.0],
    ['China', 9240270452047.0],
    ['Brazil', 2245673032353.8],
    ['South Africa', 366057913367.1]
]

headings = ['Country', GDP_USD]
gdp = pd.DataFrame(columns=headings, data=table)

def roundToMillions(value):
    return round(value / 1_000_000)

def usdToGbp(usd):
    return usd / 1.564768  # average rate during 2013

def expandCountry(name):
    if name == 'UK':
        return 'United Kingdom'
    elif name == 'USA':
        return 'United States'
    else:
        return name

# %%
# Expand country names
gdp[COUNTRY] = gdp['Country'].apply(expandCountry)

# Convert GDP to GBP and round
gdp[GDP_GBP] = gdp[GDP_USD].apply(usdToGbp).apply(roundToMillions)

# Keep only the important columns
gdp = gdp[[COUNTRY, GDP_GBP]]

# %%
headings = [COUNTRY, LIFE_EXP]
table = [
    ['China', 75],
    ['Russia', 71],
    ['United States', 79],
    ['India', 66],
    ['United Kingdom', 81]
]
life = pd.DataFrame(columns=headings, data=table)

gdpVsLife = pd.merge(gdp, life, on=COUNTRY, how='inner')
gdpVsLife
# Out:
#      Country name  GDP (£m)  Life expectancy (years)
# 0  United Kingdom   1711727                       81
# 1   United States  10716029                       79
# 2           China   5905202                       75

# %%
table = [
    ['United Kingdom', 66000000],
    ['United States', 331000000],
    ['China', 1400000000],
    ['India', 1380000000],
    ['Brazil', 213000000],
    ['South Africa', 60000000],
    ['Russia', 146000000]
]

headings = ['Country name', 'Population']
population = pd.DataFrame(columns=headings, data=table)

# Example: Inner join with population
merged = pd.merge(gdpVsLife, population, on=COUNTRY, how='inner')
merged
# Out:
#      Country name  GDP (£m)  Life expectancy (years)  Population
# 0  United Kingdom   1711727                       81    66000000
# 1   United States  10716029                       79   331000000
# 2           China   5905202                       75  1400000000

# %% [markdown]
# ## Provide Notebook-2 Tasks Solutions below (Execute them)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dde0c084-8848-4183-8ca1-f519c5ab2cd8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dde0c084-8848-4183-8ca1-f519c5ab2cd8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

GDP_INDICATOR = 'NY.GDP.MKTP.CD'
gdpReset = pd.read_csv('WB GDP 2013.csv')

LIFE_INDICATOR = 'SP.DYN.LE00.IN'
lifeReset = pd.read_csv('WB LE 2013.csv')

#Adding the population data
POP_INDICATOR = 'SP.POP.TOTL'  #World Bank indicator for total population
popReset = pd.read_csv('WB POP 2013.csv')
popReset.head()
# Out:
#                                    country  year   SP.POP.TOTL
# 0                               Arab World  2013  3.770967e+08
# 1                   Caribbean small states  2013  6.975819e+06
# 2           Central Europe and the Baltics  2013  1.037137e+08
# 3  East Asia & Pacific (all income levels)  2013  2.248867e+09
# 4    East Asia & Pacific (developing only)  2013  2.006073e+09

# %%
#Data Cleaning
#Filtering from the first country downwards
gdpCountries = gdpReset[34:]
lifeCountries = lifeReset[34:]
popCountries = popReset[34:]

#Removing missing values(r0ws with missing data)
gdpData = gdpCountries.dropna()
lifeData = lifeCountries.dropna()
popData = popCountries.dropna()

# %%
#Keeping only the useful columns
COUNTRY = 'country'

headings = [COUNTRY, GDP_INDICATOR]
gdpClean = gdpData[headings]

headings = [COUNTRY, LIFE_INDICATOR]
lifeClean = lifeData[headings]

headings = [COUNTRY, POP_INDICATOR]
popClean = popData[headings]

# %%
#Merging the GDP and Life Expectancy data
gdpVsLifeAll = pd.merge(gdpClean, lifeClean, on=COUNTRY, how='inner')
gdpVsLifeAll.head()
# Out:
#                country  NY.GDP.MKTP.CD  SP.DYN.LE00.IN
# 0          Afghanistan    2.045894e+10       60.028268
# 1              Albania    1.278103e+10       77.537244
# 2              Algeria    2.097035e+11       74.568951
# 3               Angola    1.383568e+11       51.866171
# 4  Antigua and Barbuda    1.200588e+09       75.778659

# %%
#Converting GDP (USD) to Million Pounds (£m)
GDP = 'GDP (£m)'
column = gdpVsLifeAll[GDP_INDICATOR]
gdpVsLifeAll[GDP] = column.apply(usdToGBP).apply(roundToMillions)

#Rounding Life Expectancy to whole numbers
LIFE = 'Life expectancy (years)'
gdpVsLifeAll[LIFE] = gdpVsLifeAll[LIFE_INDICATOR].apply(round)

#Keeping only the clean and relevant columns
headings = [COUNTRY, GDP, LIFE]
gdpVsLifeClean = gdpVsLifeAll[headings]
gdpVsLifeClean.head()
# Out:
#                country  GDP (£m)  Life expectancy (years)
# 0          Afghanistan     13075                       60
# 1              Albania      8168                       78
# 2              Algeria    134016                       75
# 3               Angola     88420                       52
# 4  Antigua and Barbuda       767                       76

# %% [markdown]
# ### Tasks
#
# 1. Merge `gdpVsLifeClean` with the population dataframe obtained in the previous exercise.
# - Round the population value to the nearest million.
# - Remove the original population column.

# %%
POP_INDICATOR = 'SP.POP.TOTL'

populationCountries = popReset[34:]      # start from row 34 to remove region aggregates
populationData = populationCountries.dropna()   #drop missing values

COUNTRY = 'country'
headings = [COUNTRY, POP_INDICATOR]
popClean = populationData[headings]

# %%
gdp_life_pop = pd.merge(gdpVsLifeClean, popClean, on='country', how='inner')

# %%
#Rounding population to millions
gdp_life_pop['Population (millions)'] = gdp_life_pop['SP.POP.TOTL'].apply(lambda x: round(x / 1_000_000))

#Dropping the original population column
gdp_life_pop = gdp_life_pop.drop(columns=['SP.POP.TOTL'])
gdp_life_pop.head()
# Out:
#                country  GDP (£m)  Life expectancy (years)  \
# 0          Afghanistan     13075                       60
# 1              Albania      8168                       78
# 2              Algeria    134016                       75
# 3               Angola     88420                       52
# 4  Antigua and Barbuda       767                       76
#
#    Population (millions)
# 0                     31
# 1                      3
# 2                     38
# 3                     23
# 4                      0

# %% [markdown]
# ### Task
#
# Calculate the correlation between GDP and population.

# %%
from scipy.stats import spearmanr

gdpColumn = gdp_life_pop['GDP (£m)']
popColumn = gdp_life_pop['Population (millions)']

# Calculating Spearman correlation and p-value
(correlation, pValue) = spearmanr(gdpColumn, popColumn)

print('The correlation between GDP and population is', correlation)
if pValue < 0.05:
    print('It is statistically significant.')
else:
    print('It is not statistically significant.')
# Out:
# The correlation between GDP and population is 0.7056367228611176
# It is statistically significant.

# %% [markdown]
# ### Tasks
#
# - Swap the axes of the scatterplot, i.e. show the GDP in the y axis and the life expectancy in the x axis.
# - Display a scatterplot of the GDP and the population.

# %%
#Swapping the axes of the scatterplot, i.e. show the GDP in the y axis and the life expectancy in the x axis.
gdpVsLifeClean.plot(
    x=LIFE,
    y=GDP,
    kind='scatter',
    grid=True,
    logy=True,
    figsize=(10, 4)
)
# Out:
# <Axes: xlabel='Life expectancy (years)', ylabel='GDP (£m)'>

# %%
#Displaying a scatterplot of the GDP and the population.
gdp_life_pop.plot(
    x='Population (millions)',
    y=GDP,
    kind='scatter',
    grid=True,
    logy=True,
    figsize=(10, 4)
)
# Out:
# <Axes: xlabel='Population (millions)', ylabel='GDP (£m)'>

# %% [markdown]
# ## Provide Notebook-2 Assignment Solutions below (Execute them)

# %% [markdown]
# - To what extent do the ten countries with the highest GDP coincide with the ten
# countries with the longest life expectancy?

# %%
top10_gdp = gdp_life_pop.nlargest(10, 'GDP (£m)')
top10_life = gdp_life_pop.nlargest(10, 'Life expectancy (years)')

common_countries = set(top10_gdp['country']).intersection(set(top10_life['country']))
print("Countries in both top 10:", common_countries)
# Out:
# Countries in both top 10: {'Japan', 'Italy', 'France'}

# %% [markdown]
# ### Analysis
# The comparison between the top 10 countries by GDP and by life expectancy shows that only Japan, Italy, and France appear in both lists.
# This indicates that while economic strength often supports better healthcare and living conditions,
# high GDP alone does not ensure the longest life expectancy.
# Social, cultural, and healthcare factors also play a major role.

# %% [markdown]
# - Which are the two countries in the right half of the plot (higher GDP) with life
# expectancy below 60 years?
# - What factors could explain their lower life
# expectancy compared to countries with similar GDP?
# Hint: use the filtering techniques you learned in Week 2 to find the two countries.

# %%
# Calculating the median GDP
median_gdp = gdp_life_pop['GDP (£m)'].median()

# Filtering for higher-GDP countries with low life expectancy
low_life_high_gdp = gdp_life_pop[
    (gdp_life_pop['GDP (£m)'] > median_gdp) &
    (gdp_life_pop['Life expectancy (years)'] < 60)
]

low_life_high_gdp
# Out:
#           country  GDP (£m)  Life expectancy (years)  Population (millions)
# 3          Angola     88420                       52                     23
# 124       Nigeria    329100                       52                    173
# 152  South Africa    234056                       57                     53

# %% [markdown]
# ### Countries with High GDP but Low Life Expectancy
#
# The analysis identified **Angola**, **Nigeria**, and **South Africa** as countries with relatively high GDP values but life expectancy below 60 years.
# Despite their strong economies compared to many others on the continent, several factors may explain their lower life expectancy:
#
# - **Unequal wealth distribution** – A large portion of the national GDP is often concentrated among a small segment of the population, meaning that most citizens do not benefit directly from the country's economic strength.
# - **Public health challenges** – Diseases such as HIV/AIDS, malaria, and other preventable illnesses remain prevalent and can significantly impact average lifespan.
# - **Healthcare access and infrastructure** – Limited access to quality healthcare services, especially in rural areas, can lead to poorer health outcomes.
# - **Political or social factors** – Corruption, conflict, and economic instability may divert resources away from healthcare, education, and social welfare systems.
#
# Overall, this finding highlights that a higher national GDP does not necessarily translate into better quality of life or improved health outcomes for the population.
# It underscores the importance of equitable development and investment in healthcare alongside economic growth.

# %%
# Creating a new column for GDP per capita
gdp_life_pop['GDP per capita (£)'] = (gdp_life_pop['GDP (£m)'] * 1_000_000) / gdp_life_pop['Population (millions)']

# top 10 countries by GDP per capita
gdp_life_pop.sort_values(by='GDP per capita (£)', ascending=False).head(10)
# Out:
#                 country  GDP (£m)  Life expectancy (years)  \
# 4   Antigua and Barbuda       767                       76
# 10         Bahamas, The      5388                       75
# 18              Bermuda      3562                       81
# 16               Belize      1038                       70
# 13             Barbados      2736                       75
# 24    Brunei Darussalam     10296                       79
# 55       Faeroe Islands      1670                       81
# 87             Kiribati       108                       66
# 74              Iceland      9827                       83
# 65              Grenada       538                       73
#
#     Population (millions)  GDP per capita (£)
# 4                       0                 inf
# 10                      0                 inf
# 18                      0                 inf
# 16                      0                 inf
# 13                      0                 inf
# ...

# %%
# Scatter plot
gdp_life_pop.plot(
    x='GDP per capita (£)',
    y='Life expectancy (years)',
    kind='scatter',
    grid=True,
    logx=True,
    figsize=(10, 5)
)
# Out:
# <Axes: xlabel='GDP per capita (£)', ylabel='Life expectancy (years)'>

# %% [markdown]
# ### GDP per Capita vs Life Expectancy
#
# Using GDP per capita instead of total GDP allows for fairer comparison between countries of different population sizes.
# The scatterplot shows that countries with higher GDP per person generally have longer life expectancy,
# suggesting that individual wealth is more closely linked to health and quality of life than overall national wealth.

# %% [markdown]
# # Read and follow the below example analysis

# %% [markdown]
# # GDP and life expectancy
#
# Richer countries can afford to invest more on healthcare, on work and road safety, and other measures that reduce mortality. On the other hand, richer countries may have less healthy lifestyles. Is there any relation between the wealth of a country and the life expectancy of its inhabitants?
#
# The following analysis checks whether there is any correlation between the total gross domestic product (GDP) of a country in 2013 and the life expectancy of people born in that country in 2013.

# %% [markdown]
# ## Getting the data
#
# Two datasets of the World Bank are considered. One dataset, available at <http://data.worldbank.org/indicator/NY.GDP.MKTP.CD>, lists the GDP of the world's countries in current US dollars, for various years. The use of a common currency allows us to compare GDP values across countries. The other dataset, available at <http://data.worldbank.org/indicator/SP.DYN.LE00.IN>, lists the life expectancy of the world's countries. The datasets were downloaded as CSV files in March 2016.

# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

import pandas as pd

YEAR = 2013
GDP_INDICATOR = 'NY.GDP.MKTP.CD'
gdpReset = pd.read_csv('WB GDP 2013.csv')

LIFE_INDICATOR = 'SP.DYN.LE00.IN'
lifeReset = pd.read_csv('WB LE 2013.csv')
lifeReset.head()
# Out:
#                                    country  year  SP.DYN.LE00.IN
# 0                               Arab World  2013       70.631305
# 1                   Caribbean small states  2013       71.901964
# 2           Central Europe and the Baltics  2013       76.127583
# 3  East Asia & Pacific (all income levels)  2013       74.604619
# 4    East Asia & Pacific (developing only)  2013       73.657617

# %% [markdown]
# ## Cleaning the data
#
# Inspecting the data with `head()` and `tail()` shows that:
#
# 1. the first 34 rows are aggregated data, for the Arab World, the Caribbean small states, and other country groups used by the World Bank;
# - GDP and life expectancy values are missing for some countries.
#
# The data is therefore cleaned by:
# 1. removing the first 34 rows;
# - removing rows with unavailable values.

# %%
gdpCountries = gdpReset[34:].dropna()
lifeCountries = lifeReset[34:].dropna()

# %% [markdown]
# ## Transforming the data
#
# The World Bank reports GDP in US dollars and cents. To make the data easier to read, the GDP is converted to millions of British pounds (the author's local currency) with the following auxiliary functions, using the average 2013 dollar-to-pound conversion rate provided by <http://www.ukforex.co.uk/forex-tools/historical-rate-tools/yearly-average-rates>.

# %%
def roundToMillions (value):
    return round(value / 1000000)

def usdToGBP (usd):
    return usd / 1.564768

GDP = 'GDP (£m)'
gdpCountries[GDP] = gdpCountries[GDP_INDICATOR].apply(usdToGBP).apply(roundToMillions)
gdpCountries.head()
# Out:
#         country  year  NY.GDP.MKTP.CD  GDP (£m)
# 34  Afghanistan  2013    2.045894e+10     13075
# 35      Albania  2013    1.278103e+10      8168
# 36      Algeria  2013    2.097035e+11    134016
# 38      Andorra  2013    3.249101e+09      2076
# 39       Angola  2013    1.383568e+11     88420

# %% [markdown]
# The unnecessary columns can be dropped.

# %%
COUNTRY = 'country'
headings = [COUNTRY, GDP]
gdpClean = gdpCountries[headings]
gdpClean.head()
# Out:
#         country  GDP (£m)
# 34  Afghanistan     13075
# 35      Albania      8168
# 36      Algeria    134016
# 38      Andorra      2076
# 39       Angola     88420

# %% [markdown]
# The World Bank reports the life expectancy with several decimal places. After rounding, the original column is discarded.

# %%
LIFE = 'Life expectancy (years)'
lifeCountries[LIFE] = lifeCountries[LIFE_INDICATOR].apply(round)
headings = [COUNTRY, LIFE]
lifeClean = lifeCountries[headings]
lifeClean.head()
# Out:
#                 country  Life expectancy (years)
# 34          Afghanistan                       60
# 35              Albania                       78
# 36              Algeria                       75
# 39               Angola                       52
# 40  Antigua and Barbuda                       76

# %% [markdown]
# ## Combining the data
#
# The tables are combined through an inner join on the common 'country' column.

# %%
gdpVsLife = merge(gdpClean, lifeClean, on=COUNTRY, how='inner')
gdpVsLife.head()
# Out:
#                country  GDP (£m)  Life expectancy (years)
# 0          Afghanistan     13075                       60
# 1              Albania      8168                       78
# 2              Algeria    134016                       75
# 3               Angola     88420                       52
# 4  Antigua and Barbuda       767                       76

# %% [markdown]
# ## Calculating the correlation
#
# To measure if the life expectancy and the GDP grow together, the Spearman rank correlation coefficient is used. It is a number from -1 (perfect inverse rank correlation: if one indicator increases, the other decreases) to 1 (perfect direct rank correlation: if one indicator increases, so does the other), with 0 meaning there is no rank correlation. A perfect correlation doesn't imply any cause-effect relation between the two indicators. A p-value below 0.05 means the correlation is statistically significant.

# %%
from scipy.stats import spearmanr

gdpColumn = gdpVsLife[GDP]
lifeColumn = gdpVsLife[LIFE]
(correlation, pValue) = spearmanr(gdpColumn, lifeColumn)
print('The correlation is', correlation)
if pValue < 0.05:
    print('It is statistically significant.')
else:
    print('It is not statistically significant.')
# Out:
# The correlation is 0.501023238967
# It is statistically significant.

# %% [markdown]
# The value shows a direct correlation, i.e. richer countries tend to have longer life expectancy, but it is not very strong.

# %% [markdown]
# ## Showing the data
#
# Measures of correlation can be misleading, so it is best to see the overall picture with a scatterplot. The GDP axis uses a logarithmic scale to better display the vast range of GDP values, from a few million to several billion (million of million) pounds.

# %%
# %matplotlib inline
gdpVsLife.plot(x=GDP, y=LIFE, kind='scatter', grid=True, logx=True, figsize=(10, 4))

# %% [markdown]
# The plot shows there is no clear correlation: there are rich countries with low life expectancy, poor countries with high expectancy, and countries with around 10 thousand (10<sup>4</sup>) million pounds GDP have almost the full range of values, from below 50 to over 80 years. Towards the lower and higher end of GDP, the variation diminishes. Above 40 thousand million pounds of GDP (3rd tick mark to the right of 10<sup>4</sup>), most countries have an expectancy of 70 years or more, whilst below that threshold most countries' life expectancy is below 70 years.
#
# Comparing the 10 poorest countries and the 10 countries with the lowest life expectancy shows that total GDP is a rather crude measure. The population size should be taken into account for a more precise definiton of what 'poor' and 'rich' means. Furthermore, looking at the countries below, droughts and internal conflicts may also play a role in life expectancy.

# %%
# the 10 countries with lowest GDP
gdpVsLife.sort_values(GDP).head(10)
# Out:
#                             country  GDP (£m)  Life expectancy (years)
# 87                         Kiribati       108                       66
# 141           Sao Tome and Principe       195                       66
# 111           Micronesia, Fed. Sts.       202                       69
# 168                           Tonga       277                       73
# 37                          Comoros       383                       63
# 157  St. Vincent and the Grenadines       461                       73
# 140                           Samoa       509                       73
# 180                         Vanuatu       512                       72
# 65                          Grenada       538                       73
# 60                      Gambia, The       578                       60

# %%
# the 10 countries with lowest life expectancy
gdpVsLife.sort_values(LIFE).head(10)
# Out:
#                       country  GDP (£m)  Life expectancy (years)
# 95                    Lesotho      1418                       49
# 160                 Swaziland      2916                       49
# 32   Central African Republic       983                       50
# 146              Sierra Leone      3092                       50
# 33                       Chad      8276                       51
# 41              Cote d'Ivoire     19998                       51
# 3                      Angola     88420                       52
# 124                   Nigeria    329100                       52
# 30                   Cameroon     18896                       55
# 153               South Sudan      8473                       55

# %% [markdown]
# ## Conclusions
#
# To sum up, there is no strong correlation between a country's wealth and the life expectancy of its inhabitants: there is often a wide variation of life expectancy for countries with similar GDP, countries with the lowest life expectancy are not the poorest countries, and countries with the highest expectancy are not the richest countries. Nevertheless there is some relationship, because the vast majority of countries with a life expectancy below 70 years is on the left half of the scatterplot.
#
# Using the [NY.GDP.PCAP.PP.CD](http://data.worldbank.org/indicator/NY.GDP.PCAP.PP.CD) indicator, GDP per capita in current 'international dollars', would make for a better like-for-like comparison between countries, because it would take population and purchasing power into account. Using more specific data, like expediture on health, could also lead to a better analysis.

# %% [markdown]
# ## Assessment - NOW IS YOUR TURN
#
# **Create your own project**
# Create a completely new project and choose another two of the
# hundreds of World Bank indicators and see if there is any correlation between them. If
# there is a choice of similar indicators, choose one that leads to meaningful
# comparisons between countries.
#
# Look at the results you obtained and take a few moments to assess how they differ.
#
#
# ## GOOD LUCK!

# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

from google.colab import files
uploaded = files.upload()

import pandas as pd
# Out:
#      <input type="file" id="files-bf368643-cfee-4087-8099-fc63ce4e0fa0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf368643-cfee-4087-8099-fc63ce4e0fa0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Read GDP CSV
gdp = pd.read_csv(
    'GDP_per_capita.csv',
    skiprows=4,          # skip metadata rows
    engine='python',     # better parsing for mixed quoted/unquoted columns
    quotechar='"',       # handle quotes
    skipinitialspace=True  # remove spaces after commas
)

# Read School enrollment CSV
school = pd.read_csv(
    'School_enrollment.csv',
    skiprows=4,
    engine='python',
    quotechar='"',
    skipinitialspace=True
)

# Strip whitespace from columns
gdp.columns = gdp.columns.str.strip()
school.columns = school.columns.str.strip()

# Check columns
print(gdp.columns)
print(school.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
# ...

# %%
#Selecting 2023 data
gdp_2023 = gdp[['Country Name', '2023']].copy()
school_2023 = school[['Country Name', '2023']].copy()

# Rename the columns for clarity
school_2023.columns = ['Country', 'Tertiary Enrollment (%)']
gdp_2023.columns = ['Country', 'GDP per Capita (US$)']

print(gdp_2023.head())
print(school_2023.head())
# Out:
#                        Country  GDP per Capita (US$)
# 0                        Aruba          33984.790620
# 1  Africa Eastern and Southern           1510.742951
# 2                  Afghanistan            413.757895
# 3   Africa Western and Central           1599.392983
# 4                       Angola           2309.534130
#                        Country  Tertiary Enrollment (%)
# 0                        Aruba                      NaN
# 1  Africa Eastern and Southern                      NaN
# 2                  Afghanistan                      NaN
# 3   Africa Western and Central                      NaN
# 4                       Angola                10.049358

# %%
#Dropping missing data
gdp_2023.dropna(inplace=True)
school_2023.dropna(inplace=True)

#Merging datasets on Country
gdpVssch = pd.merge(gdp_2023, school_2023, on='Country', how='inner')
gdpVssch.head()
# Out:
#                 Country  GDP per Capita (US$)  Tertiary Enrollment (%)
# 0                Angola           2309.534130                10.049358
# 1               Albania           8575.171346                64.729352
# 2               Andorra          46812.448449                62.410694
# 3            Arab World           7479.688091                33.245640
# 4  United Arab Emirates          49040.694752                61.345611

# %%
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

#Computing Spearman correlation
GDP = 'GDP per Capita (US$)'
TERTIARY = 'Tertiary Enrollment (%)'

gdpColumn = gdpVssch[GDP]
tertiaryColumn = gdpVssch[TERTIARY]

(correlation, pValue) = spearmanr(gdpColumn, tertiaryColumn)
print('The correlation is', round(correlation, 3))
if pValue < 0.05:
    print('It is statistically significant.')
else:
    print('It is not statistically significant.')
# Out:
# The correlation is 0.726
# It is statistically significant.

# %% [markdown]
# A Spearman correlation of 0.726 indicates a strong positive relationship between GDP per capita and tertiary school enrollment in 2023.
# - Interpretation: Wealthier countries tend to have higher tertiary enrollment rates.

# %%
#Scatterplot (log scale for GDP)

plt.figure(figsize=(10,5))
plt.scatter(gdpVssch['GDP per Capita (US$)'], gdpVssch['Tertiary Enrollment (%)'], color='teal', edgecolor='k')
plt.xscale('log')
plt.xlabel('GDP per Capita (US$) [log scale]')
plt.ylabel('Tertiary Enrollment (%)')
plt.title('Tertiary School Enrollment vs GDP per Capita (2023)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### **Tertiary School Enrollment vs GDP per Capita (2023)**
#
# **Summary of Findings**
#
# The scatterplot above illustrates the relationship between GDP per capita and tertiary school enrollment for 2023.
# A clear upward trend can be observed, countries with higher GDP per capita generally have higher enrollment rates in tertiary education.
#
# This positive pattern supports the idea that strong economic performance enhances access to higher education, likely through greater national investment in universities, financial aid, and infrastructure.
# However, the chart also reveals visible dispersion and a few notable outliers — some countries with modest GDP levels achieve relatively high enrollment, while others with high GDP lag behind.
# This suggests that factors beyond wealth, such as government policies, educational priorities, and cultural emphasis on learning, play a significant role.
#
# In summary, while economic strength is an important driver of higher education participation, it is not the sole determinant. Countries that invest strategically in education tend to outperform others regardless of income level.

# %% [markdown]
# # **Link to Publication**

# %% [markdown]
# https://papizee.hashnode.dev/from-data-chaos-to-insight-analyzing-gdp-and-education-with-python-and-pandas
